# %% [markdown]
# # Advanced Lane Finding
#
# The goals / steps of this project are the following:
#
# * Compute the camera calibration matrix and distortion coefficients given a set of chessboard images.
# * Apply a distortion correction to raw images.
# * Use color transforms, gradients, etc., to create a thresholded binary image.
# * Apply a perspective transform to rectify binary image ("birds-eye view").
# * Detect lane pixels and fit to find the lane boundary.
# * Determine the curvature of the lane and vehicle position with respect to center.
# * Warp the detected lane boundaries back onto the original image.
# * Output visual display of the lane boundaries and numerical estimation of lane curvature and vehicle position.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import os
from ipywidgets import interact, interactive, fixed
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %% [markdown]
# ## Camera Calibration

# %%
import glob
# Making a list of calibration images
cal_images = glob.glob('./camera_cal/calibration*.jpg')

# prepare object points
nx = 9 #TODO: enter the number of inside corners in x
ny = 6 #TODO: enter the number of inside corners in y

# prepare object pts
objp = np.zeros((nx*ny,3),np.float32)
objp[:,0:2] =np.mgrid[0:nx,0:ny].T.reshape(-1,2)

# Arrays to store object and impage points from all the images

objpoints = []  # 3D points in real world space
imgpoints = []  # 2D points in image plane

fig, axs = plt.subplots(5,4, figsize=(15, 10))
fig.subplots_adjust(hspace = .15, wspace=.15)

axs = axs.ravel()
for idx, fname in enumerate(cal_images):
    img = cv2.imread(fname)
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Find the chessboard corners
    ret, corners = cv2.findChessboardCorners(gray, (nx,ny), None)
    # If found, add object points, image points
    if ret == True:
        objpoints.append(objp)
        imgpoints.append(corners)
        
        # Draw and plot the cornersimg = cv2.drawChessboardCorners(img, (9,6), corners, ret)
        img = cv2.drawChessboardCorners(img, (nx,ny), corners, ret)
        axs[idx].axis('off')
        axs[idx].imshow(img)

# %% [markdown]
# The images that do not appear in the display are those where the specificied no. of corners were not detected.

# %% [markdown]
# # Distortion Correction

# %%
img_size = (img.shape[1], img.shape[0])
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img_size,None,None)
def cal_undistort(img, objpoints, imgpoints):
    # Use cv2.calibrateCamera() and cv2.undistort()
    
    undist = cv2.undistort(img, mtx, dist, None, mtx)
    return undist

# %% [markdown]
# ### Visualizing Distorion

# %%
img = cv2.imread('./camera_cal/calibration1.jpg')
undist = cal_undistort(img, objpoints, imgpoints)

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,10))
f.subplots_adjust(hspace = .15, wspace=.15)
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=30)
ax2.imshow(undist)
ax2.set_title('Undistorted Image', fontsize=30)

# %%
n = 1
list = os.listdir('./test_images')
img = mpimg.imread('./test_images/{}'.format(list[n]))
undistorted = cal_undistort(img, objpoints, imgpoints)

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
f.tight_layout()
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=40)
ax2.imshow(undistorted)
ax2.set_title('Undistorted Image', fontsize=40)
plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)

# %% [markdown]
# # Color/gradient threshold

# %%
def colorAndThreshold(img, s_thresh = (150,255), sx_thresh = (20,100)):
    img = np.copy(img)
    R = img[:,:,0].astype(np.float)
    # Convert to HLS color space
    hls = cv2.cvtColor(img,cv2.COLOR_RGB2HLS).astype(np.float)
    l_channel = hls[:,:,1]
    
    s_channel = hls[:,:,2]

    #Sobel x
    sobelx = cv2.Sobel(l_channel, cv2.CV_64F,1,0) # Take the der in x
    abs_sobelx = np.absolute(sobelx) # Absolute x derivative to accentuate linws away from horizontal
    scaled_sobel = np.uint8(255*abs_sobelx/np.max(abs_sobelx))

    # Threshold x gradient
    sxbinary = np.zeros_like(scaled_sobel)
    
    sxbinary[(scaled_sobel >= sx_thresh[0]) & (scaled_sobel <= sx_thresh[1])] = 1
    
    s_channel = np.uint8(255*s_channel/np.max(s_channel))
    #Threshold color channel 
    s_binary = np.zeros_like(s_channel)
    s_binary = np.uint8(255*s_binary/np.max(s_binary))
    s_binary[(s_channel >= s_thresh[0]) & (s_channel <= s_thresh[1])] = 1
    #print(s_binary)
    
    l_channel = np.uint8(255*l_channel/np.max(l_channel))
    #Threshold l channel
    l_binary = np.zeros_like(l_channel)
    l_binary[(l_channel >= l_thresh[0]) & (l_channel <= l_thresh[1])] = 1
    
    R = np.uint8(255*R/np.max(R))
    #Threshold l channel
    R_binary = np.zeros_like(R)
    R_binary[(R >= R_thresh[0]) & (R <= R_thresh[1])] = 1

    # Stack each channel ton view their individual contributions in green and blue respectively
    color_binary = 255*np.dstack((np.zeros_like(s_binary),l_binary, s_binary))
    
    #Combination of two binary thresholds
    combined_binary = np.zeros_like(s_binary)
    combined_binary[(sxbinary==1)|(l_binary ==1) | ((R_binary==1)&s_binary==1)]= 1
    
    return combined_binary,color_binary

# %% [markdown]
# Visulaizing color gradients/thresholding

# %%
l_thresh = (210,255)
R_thresh =(180,255)
s_thresh = (150,255)
sx_thresh = (40,100)
img = cv2.imread('./test_images/test1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
undistorted = cal_undistort(img, objpoints, imgpoints)

combined_binary,color_binary = colorAndThreshold(undistorted,s_thresh ,sx_thresh)
#print(color_binary)
# Plotting thresholded images

f, (ax1,ax2,ax3) = plt.subplots(1,3, figsize = (20,10))

ax1.set_title('Undistorted')
ax1.imshow(undistorted)

ax2.set_title('Stacked thresholds')
ax2.imshow(color_binary)

ax3.set_title('Combined s channel and gradient thresholds')
ax3.imshow(combined_binary, cmap = 'gray')

# %% [markdown]
# # Perspective Transfomation

# %%
def unwrap(img,src,dst):
    img_size =(img.shape[1],img.shape[0])
    
    # Given src and dst points, calculate the perspective transform matrix
    M = cv2.getPerspectiveTransform(src, dst)
    invM = cv2.getPerspectiveTransform(dst,src)
    warped = cv2.warpPerspective(img, M, img_size)
    return warped, M,invM

# %% [markdown]
# Visualizing

# %%
def draw_lines(img, lines, color=[255, 0, 0], thickness=2):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    for line in lines:
        for x1,y1,x2,y2 in line:
            cv2.line(img, (x1, y1), (x2, y2), color, thickness)
            
def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

def regionofInterestforPerspectiveTransformation(img,src):
    point1 = src[0]
    point2 = src[1]
    point3 = src[2]
    point4 = src[3]

    # vertices lines is the region of interest formed by lines
    vertices_lines=np.array([[[point1[0],point1[1],point2[0],point2[1]],[point2[0],point2[1],point3[0],point3[1]],\
                             [point3[0],point3[1],point4[0],point4[1]],\
                            [point4[0],point4[1],point1[0],point1[1]]]],dtype=np.int32)
    draw_poly = np.zeros_like(img)
    draw_poly = np.uint8(draw_poly)
    draw_lines(draw_poly,vertices_lines,color=[255,0,0],thickness=10)
    merge = weighted_img(img, draw_poly, α=1, β=1., λ=0.)
    return merge

# %%
print(img.shape)
h= img.shape[0]
w = img.shape[1]
#src = np.float32([[290,img.shape[0]-50],[570,470],[770,470],[1120,img.shape[0]-50]])

src = np.float32([(190,720),(570,460),(710,460),(1180,720)])
dst = np.float32([(360,h),(360,0),(w-360,0),(w-360,h)])
print(src)
print(dst)
warped,M,invM = unwrap(combined_binary,src,dst)
merge = regionofInterestforPerspectiveTransformation(undistorted,src)

fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(40,20))
ax1.imshow(undistorted)
ax2.imshow(merge)
ax3.imshow(combined_binary,cmap = 'gray')
ax4.imshow(warped,cmap = 'gray')
# Out:
# (720, 1280, 3)
# [[  190.   720.]
#  [  570.   460.]
#  [  710.   460.]
#  [ 1180.   720.]]
# [[ 360.  720.]
#  [ 360.    0.]
#  [ 920.    0.]
#  [ 920.  720.]]

# %%
print(plt.imshow(warped,cmap='gray'))
# Out:
# AxesImage(54,36;334.8x217.44)

# %% [markdown]
# # Image Processing Pipeline

# %%
def pipeline(img,src,dst,objpoints, imgpoints,s_thresh=(190,255),sx_thresh=(20,100)):
    
    undistorted = cal_undistort(img,objpoints, imgpoints)
    combined_binary,color_binary = colorAndThreshold(undistorted,s_thresh,sx_thresh)
    warped,M,invM = unwrap(combined_binary,src,dst)
    merge = regionofInterestforPerspectiveTransformation(undistorted,src)
    return undistorted,combined_binary,warped,merge,invM

# %% [markdown]
# ### Run pipeline function on all test images

# %%
# Make a list of example images
images = glob.glob('./test_images/*.jpg')

fig, axes = plt.subplots(len(images),4, figsize=(10, 20))
#fig.subplots_adjust(hspace = .2, wspace=.001)
axes = axes.ravel()
i = 0               
for image in images:
    img = cv2.imread(image)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    undistorted,combined_binary,warped,merge,invM = pipeline(img,src,dst,objpoints, imgpoints,s_thresh,sx_thresh)
    axes[i].imshow(undistorted)
    axes[i].axis('off')
    i = i+1
    axes[i].imshow(merge)
    axes[i].axis('off')
    i = i+1
    axes[i].imshow(combined_binary,cmap='gray')
    axes[i].axis('off')
    i = i+1
    axes[i].imshow(warped,cmap='gray')
    axes[i].axis('off')
    i = i + 1

# %% [markdown]
# #  Lane Detection

# %%
def sliding_window(img):
    binary_warped = np.copy(img)
    # Take a histogram of the bottom half of the image
    histogram = np.sum(binary_warped[binary_warped.shape[0]//2:,:], axis=0)
                       
    # Create an output image to draw on and  visualize the result
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
    # Find the peak of the left and right halves of the histogram
    # These will be the starting point for the left and right lines
    midpoint = np.int(histogram.shape[0]/2)
    leftx_base = np.argmax(histogram[:midpoint])
    rightx_base = np.argmax(histogram[midpoint:]) + midpoint

    # Choose the number of sliding windows
    nwindows = 9
    # Set height of windows
    window_height = np.int(binary_warped.shape[0]/nwindows)
    # Identify the x and y positions of all nonzero pixels in the image
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Current positions to be updated for each window
    leftx_current = leftx_base
    rightx_current = rightx_base
    # Set the width of the windows +/- margin
    margin = 75
    # Set minimum number of pixels found to recenter window
    minpix = 35
    # Create empty lists to receive left and right lane pixel indices
    left_lane_inds = []
    right_lane_inds = []

    # Step through the windows one by one
    for window in range(nwindows):
        # Identify window boundaries in x and y (and right and left)
        win_y_low = binary_warped.shape[0] - (window+1)*window_height
        win_y_high = binary_warped.shape[0] - window*window_height
        win_xleft_low = leftx_current - margin
        win_xleft_high = leftx_current + margin
        win_xright_low = rightx_current - margin
        win_xright_high = rightx_current + margin
        # Draw the windows on the visualization image
        cv2.rectangle(out_img,(win_xleft_low,win_y_low),(win_xleft_high,win_y_high),\
        (0,255,0), 5) 
        cv2.rectangle(out_img,(win_xright_low,win_y_low),(win_xright_high,win_y_high),\
        (0,255,0), 5) 
        # Identify the nonzero pixels in x and y within the window
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xleft_low) &  (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xright_low) &  (nonzerox < win_xright_high)).nonzero()[0]
        # Append these indices to the lists
        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)
        # If you found > minpix pixels, recenter next window on their mean position
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:        
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))

    # Concatenate the arrays of indices
    left_lane_inds = np.concatenate(left_lane_inds)
    right_lane_inds = np.concatenate(right_lane_inds)

    # Extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds] 

    # Fit a second order polynomial to each
    if len(leftx) != 0:
        left_fit = np.polyfit(lefty, leftx, 2)
    if len(rightx) != 0:
        right_fit = np.polyfit(righty, rightx, 2)
    return left_fit, right_fit, left_lane_inds, right_lane_inds, histogram,out_img,nonzerox,nonzeroy

# %% [markdown]
# Visualizing sliding window

# %%
Test_Images_list = os.listdir('./test_images')
Test_Image_Location = './test_images/'+Test_Images_list[0]
print(Test_Image_Location)
Test_Image1 = cv2.imread(Test_Image_Location)

# BGR to RBG image
Test_Image1 = Test_Image1[:,:,::-1]
# pipeline funciton on test image
undistorted,combined_binary,warped,merge,invM  = pipeline(Test_Image1,src,dst,objpoints,\
                                                          imgpoints,s_thresh,sx_thresh)
left_fit, right_fit, left_lane_inds, right_lane_inds, histogram,out_img,nonzerox,nonzeroy = sliding_window(warped)
plt.plot(histogram)
# Out:
# ./test_images/test1.jpg

# %% [markdown]
# This histogram plot shows that left lane starts around 400 and right lane starts around 880 . This is found by summing the white pixels in a warped image  along image height for all the points on the image width

# %%
# Creating an array of points along image height
ploty = np.linspace(0, warped.shape[0]-1, warped.shape[0])

# Finding the corresponding x axis points for left and right lane  for ploty points using left and right fit
#polynomial coefficients obtained using sliding window function
print(left_fit)
left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]

# Substituting the left lane inds in red color and right lane inds by blue color
out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]

plt.imshow(out_img)

#Plotting the left lane fit fit and right lane fit using yellow color
plt.plot(left_fitx, ploty, color='yellow',linewidth =1.2)
plt.plot(right_fitx, ploty, color='yellow',linewidth=1.2)
# Out:
# [  1.47231102e-04  -2.24577128e-01   4.76411832e+02]

# %% [markdown]
# Skiping the sliding window steps for next video frame after finding the left and right fit using sliding window

# %%
margin = 70
# Using this funcition , we only search within  the vicnity of right and left lane fit detected in previous video frame
def finding_fit_using_previous_lanefit(img,left_fit,right_fit,margin =100):
    binary_warped = np.copy(img)
    nonzero = binary_warped.nonzero()
    #print(nonzero)
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    
    # Assuming that left lane inds lie within +- margin of the left lane fit detected in previous video_Frame
    left_lane_inds = ((nonzerox > (left_fit[0]*(nonzeroy**2) + left_fit[1]*nonzeroy + 
    left_fit[2] - margin)) & (nonzerox < (left_fit[0]*(nonzeroy**2) + 
    left_fit[1]*nonzeroy + left_fit[2] + margin))) 

    #print(left_lane_inds)

    # Assuming that right lane inds lie within +- margin of the right lane fit detected in previous video_Frame
    right_lane_inds = ((nonzerox > (right_fit[0]*(nonzeroy**2) + right_fit[1]*nonzeroy + 
    right_fit[2] - margin)) & (nonzerox < (right_fit[0]*(nonzeroy**2) + 
    right_fit[1]*nonzeroy + right_fit[2] + margin)))  

    # Again, extract left and right line pixel positions for non zero pixels lying within vicinity of lane fit from
    # previous video frame
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    #print(leftx,lefty)
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]

    # Fit a second order polynomial to each
    left_fit = np.polyfit(lefty, leftx, 2)
    right_fit = np.polyfit(righty, rightx, 2)
    return leftx,lefty,rightx,righty,left_fit,right_fit

# %%
# It seems the test1.jpg and test5.jpg are in sequence. Trying finding_fit_using_previous_lanefit function
# on test5.jpg
Test_Image2 = mpimg.imread('./test_images/test5.jpg')

# Pipeline function on new image
undistorted_new,combined_binary_new,warped_new,merge_new,invM_new  = \
pipeline(Test_Image2,src,dst,objpoints,imgpoints,s_thresh,sx_thresh)

# finding_fit_using_previous_lanefit function on warped_new image
leftx_new,lefty_new,rightx_new,righty_new,left_fit_new,right_fit_new = \
finding_fit_using_previous_lanefit(warped_new,left_fit,right_fit,margin)

# Generate x and y values for plotting
ploty_new = np.linspace(0, warped_new.shape[0]-1, warped_new.shape[0] )
left_fitx_new = left_fit_new[0]*ploty_new**2 + left_fit_new[1]*ploty_new + left_fit_new[2]
right_fitx_new = right_fit_new[0]*ploty_new**2 + right_fit_new[1]*ploty_new + right_fit_new[2]

# Create an image to draw on and an image to show the selection window
out_img_new = np.dstack((warped_new, warped_new, warped_new))*255
window_img = np.zeros_like(out_img_new)

# Color in left and right line pixels is red and blue respectively
out_img_new[lefty_new, leftx_new] = [255, 0, 0]
out_img_new[righty_new, rightx_new] = [0, 0, 255]

# Generate a polygon to illustrate the search window area
# And recast the x and y points into usable format for cv2.fillPoly()

left_line_window1 = np.array([np.transpose(np.vstack([left_fitx_new-margin, ploty_new]))])
left_line_window2 = np.array([np.flipud(np.transpose(np.vstack([left_fitx_new+margin,ploty_new])))])
#print(np.transpose(np.vstack([left_fitx_new-margin, ploty_new])))
left_line_pts = np.hstack((left_line_window1, left_line_window2))

right_line_window1 = np.array([np.transpose(np.vstack([right_fitx_new-margin, ploty_new]))])
right_line_window2 = np.array([np.flipud(np.transpose(np.vstack([right_fitx_new+margin, ploty_new])))])
right_line_pts = np.hstack((right_line_window1, right_line_window2))

# Draw the lane onto the warped blank image
# Filling the left window region and right windo region by green color 
# which shows the vicinity in which lane fixels were searched and fitted
cv2.fillPoly(window_img, np.int_([left_line_pts]), (0,255, 0))
cv2.fillPoly(window_img, np.int_([right_line_pts]), (0,255, 0))
#  Adding the window_img to out_img_new
result = cv2.addWeighted(out_img_new, 1, window_img, 0.3, 0)
plt.imshow(result)
plt.plot(left_fitx_new, ploty_new, color='yellow',linewidth = 1.2)
plt.plot(right_fitx_new, ploty_new, color='yellow', linewidth = 1.2)

# %% [markdown]
# The green color in the above image shows the vicnity in which lane pixels were searched and fitted, red color shows the left lane pixels, blue color shows the right lane pixels and yellow color shows the fit through left and right lane pixels.

# %% [markdown]
# Debug cell just to find the thresholds for reasonable slope difference between two lane lines

# %%
y_eval = np.max(ploty)
plt.imshow(out_img_new)
# Left lane and right lane slope value at mid point of left lane (y = y_eval/2)
left_slope = left_fit_new[0]*y_eval + left_fit_new[1]
right_slope = right_fit_new[0]*y_eval +right_fit_new[1]

print(left_slope-right_slope)

# Draw left slope and right slope at mid point of left lane (y =y_eval/2)
left_slopex = left_slope*(ploty_new - y_eval/2)+(left_fit_new[0]*(y_eval/2)**2 + left_fit_new[1]*y_eval/2\
+ left_fit_new[2])
right_slopex = right_slope*(ploty_new - y_eval/2)+(right_fit_new[0]*(y_eval/2)**2 + right_fit_new[1]*y_eval/2\
+ right_fit_new[2])

plt.plot(left_slopex,ploty_new,color='yellow',linewidth = 1.2)
plt.plot(right_slopex,ploty_new,color='yellow',linewidth = 1.2)
plt.xlim(0,1280)
plt.ylim(0,720)
# Out:
# -0.0535998920607
# (0, 720)

# %% [markdown]
# ### Calculation of Radius of curvature

# %%
#  U.S. regulations require a minimum lane width of 12 feet or 3.7 meter and
#the dashed lane lines are 10 feet or 3 meters long each. 
# denominator(which is lane dimensions in pixels) should be taken 
#from birds eye view (after taking perspective transformation)
ym_per_pix = 30/720 # meters per pixel in y dimension, 
xm_per_pix = 3.7/480 # meters per pixel in x dimension 

# the maximum y-value, corresponding to the bottom of the image 
# where we will calculate radius of curvature
y_eval = np.max(ploty)

def calculate_rad_of_curv(left_fit,right_fit,xm_per_pix = 3.7/560, ym_per_pix = 30/720):
    
    leftx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    rightx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    # Fit new polynomials to x,y in world space
    left_fit_cr = np.polyfit(ploty*ym_per_pix, leftx*xm_per_pix, 2)
    right_fit_cr = np.polyfit(ploty*ym_per_pix, rightx*xm_per_pix, 2)
    # Calculate the new radii of curvature
    left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
    right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
    rad_curv = (left_curverad+right_curverad)/2
    return left_curverad, right_curverad,rad_curv

# %%
left_curverad, right_curverad,rad_curv  = calculate_rad_of_curv(left_fit,right_fit,xm_per_pix,ym_per_pix)
print(left_curverad, 'm', right_curverad, 'm', rad_curv, 'm')
# Out:
# 764.876218711 m 1175.32506659 m 970.100642652 m

# %% [markdown]
# ### Calculation of Vehicle Offset

# %%
img_midpoint = warped.shape[1]/2
Car_Centre = img_midpoint*xm_per_pix  # Car centre in metres
def calculate_lane_offset(left_fit,right_fit,Car_Centre = 4.93):
    # left and right lane intercept along image width 
    left_lane_intercept = left_fit[0]*y_eval**2 + left_fit[1]*y_eval + left_fit[2]
    right_lane_intercept = right_fit[0]*y_eval**2 + right_fit[1]*y_eval + right_fit[2]
    # Lane midpoint in metres
    lane_midpoint = ((left_lane_intercept + right_lane_intercept)/2)*xm_per_pix

    # Calculating Lane Offset
    Lane_Offset = Car_Centre - lane_midpoint
    return Lane_Offset

# %%
Lane_Offset = calculate_lane_offset(left_fit,right_fit,Car_Centre)
print(Lane_Offset, 'm')
# Out:
# -0.0687240943368 m

# %% [markdown]
# ### Drawing Lane on Undistorted Image

# %%
# Create an image to draw the lines on
def draw_lane_on_image(warped_img,undist,invM,left_fit,right_fit):
    warped = np.copy(warped_img)
    warp_zero = np.zeros_like(warped).astype(np.uint8)
    color_warp = np.dstack((warp_zero, warp_zero, warp_zero))

    left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    # Recast the x and y points into usable format for cv2.fillPoly()
    pts_left = np.array([np.transpose(np.vstack([left_fitx, ploty]))])
    pts_right = np.array([np.flipud(np.transpose(np.vstack([right_fitx, ploty])))])
    pts = np.hstack((pts_left, pts_right))

    # Draw the lane onto the warped blank image and filling it with green color
    cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))

    # Warp the blank back to original image space using inverse perspective matrix (Minv)
    newwarp = cv2.warpPerspective(color_warp, invM, (warped.shape[1], warped.shape[0])) 
    # Combine the result with the original image
    undist_with_lane_drawn = cv2.addWeighted(undist, 1, newwarp, 0.3, 0)
    return undist_with_lane_drawn

# %%
undist_with_lane_drawn = draw_lane_on_image(warped,undistorted,invM,left_fit,right_fit)
plt.imshow(undist_with_lane_drawn)
# fig,ax = plt.subplots(1,1,figsize =(20,10))
# ax.imshow(undist_with_lane_drawn)
# ax.title('Undistorted Image with Lane Drawn',fontsize = 16)

# %% [markdown]
# ### Function to draw lane as well as calculate & write rad of curvature & vehicle offset

# %%
def calculate_and_write_rad_and_offset(undist_with_lane_drawn,left_fit,right_fit,\
                                      xm_per_pix = 3.7/480, ym_per_pix = 30/720, Car_Centre =4.93):
                                      
    left_curverad, right_curverad,rad_curv  = calculate_rad_of_curv(left_fit,right_fit,xm_per_pix,ym_per_pix)
    Lane_Offset = calculate_lane_offset(left_fit,right_fit,Car_Centre)
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(undist_with_lane_drawn,'Radius of curvature is {:.3f} m'.format(rad_curv),(10,50), \
                                                                       font, 1.8,(255,0,0),2,cv2.LINE_AA)
    if Lane_Offset > 0:
        cv2.putText(undist_with_lane_drawn,'Vehicle is {:.3f} m right from the centre'.format(abs(Lane_Offset))\
                    ,(10,120),font,1.8,(255,0,0),2,cv2.LINE_AA)
    else:
        cv2.putText(undist_with_lane_drawn,'Vehicle is {:.3f} m left from the centre'.format(abs(Lane_Offset))\
                    ,(10,120),font,1.8,(255,0,0),2,cv2.LINE_AA)    
    return undist_with_lane_drawn

# %%
undist_with_data_drawn = calculate_and_write_rad_and_offset(undist_with_lane_drawn\
                                                            ,left_fit,right_fit,\
                                                            xm_per_pix , ym_per_pix , Car_Centre )
plt.imshow(undist_with_data_drawn)

# %% [markdown]
# ### Video Pipeline

# %%
# Defining Global variables
global i 
i = 0
global left_fit_storage 
left_fit_storage  = []
global right_fit_storage
right_fit_storage = []
global intercept_sanity_check
intercept_sanity_check =0
global curve_fit_sanity_check
curve_fit_sanity_check = 0
global left_fit
left_fit = []
global right_fit
right_fit = []

def video_pipeline(img):
    
    # Global variables
    global i 
    global left_fit_storage 
    global right_fit_storage
    global intercept_sanity_check
    global curve_fit_sanity_check
    global left_fit
    global right_fit
    
    # Pipeline function on image which does undistortion, color and gradient thresholding and
    #perspective transformation
    
    undistorted,combined_binary,warped,merge,invM  = pipeline(img,src,dst,objpoints,\
                                                          imgpoints,s_thresh,sx_thresh)
    
    # If lanes are parallel enough and distance btw left & right lane is reasonable enough
    # use finding_fit_using_previous_lane_fit_function
    # else use sliding window
    
    if (intercept_sanity_check == 1 & curve_fit_sanity_check == 1):
        leftx,lefty,rightx,righty,left_fit,right_fit= \
        finding_fit_using_previous_lanefit(warped,left_fit,right_fit,margin)
        #print('used_previous_fit')

    else:
        #Sliding window
        left_fit, right_fit, left_lane_inds, right_lane_inds, histogram,out_img,\
        nonzerox,nonzeroy = sliding_window(warped)
        #print('used sliding window')
        
    # Checking the sanity for distance between right & left lane
    left_lane_intercept = left_fit[0]*y_eval**2 + left_fit[1]*y_eval + left_fit[2]
    right_lane_intercept = right_fit[0]*y_eval**2 + right_fit[1]*y_eval + right_fit[2]
    dist_btw_lanes = right_lane_intercept - left_lane_intercept
    intercept_sanity_check =  500 < dist_btw_lanes < 600
    
    # Checking if the left and right lane are reasonably parallel by computing
    #slope at y = max(y)/2
    
    left_slope = left_fit[0]*y_eval + left_fit[1]
    right_slope =right_fit[0]*y_eval + right_fit[1]
    curve_fit_sanity_check = abs(left_slope - right_slope) < 0.14

    
#     print(dist_btw_lanes,abs(left_slope - right_slope))

    ''' 
    The following code can be used if we want to store the curve fit coefficents and then smooten them by
    using averaging or some kind of weightage technique.
    Currently, this code is not being used but can be helpful for challenge videos after perfecting and 
    testing it
    '''
#     left_fit_storage.append(left_fit)
#     right_fit_storage.append(right_fit)

#     if (((intercept_sanity_check ==1)&(curve_fit_sanity_check == 1))&(len(left_fit_storage) > 4)):
#         left_fit_storage = left_fit_storage[1:]
#         right_fit_storage = right_fit_storage[1:]
#     elif(((intercept_sanity_check ==1)&(curve_fit_sanity_check == 1))&(len(left_fit_storage) <= 4)):
#         left_fit_storage = left_fit_storage[0:]
#         right_fit_storage = right_fit_storage[0:]
#     elif(((intercept_sanity_check !=1)|(curve_fit_sanity_check != 1))&(len(left_fit_storage) > 4)):
#         left_fit_storage = left_fit_storage[1:-1]   # 
#         right_fit_storage = right_fit_storage[1:-1]
#     else:
#         left_fit_storage = left_fit_storage[0:]
#         right_fit_storage = right_fit_storage[0:]

#     left_fit_avg = np.sum(np.vstack(left_fit_storage),axis = 0)/len(np.vstack(left_fit_storage))
#     right_fit_avg = np.sum(np.vstack(right_fit_storage),axis = 0)/len(np.vstack(right_fit_storage))

    # Draw lane on undistorted image
    undist_with_lane_drawn = draw_lane_on_image(warped,undistorted,invM,left_fit,right_fit)
    
    # Writing radius of curvature and vehicle offset on image with lane drawn
    
    undist_with_data_drawn = calculate_and_write_rad_and_offset(undist_with_lane_drawn\
                                                            ,left_fit,right_fit,\
                                                            xm_per_pix , ym_per_pix , Car_Centre )
    
    return undist_with_data_drawn

# %% [markdown]
# ### Project Video

# %%
video_output1 = 'project_video_output.mp4'
video_input1 = VideoFileClip('project_video.mp4')
# Use .subclip(t1,t2) to select a segment of video
processed_video = video_input1.fl_image(video_pipeline)#.subclip(18,26)
# %time processed_video.write_videofile(video_output1, audio=False)
# Out:
# [MoviePy] >>>> Building video project_video_output.mp4
# [MoviePy] Writing video project_video_output.mp4
# 100%|█████████▉| 1260/1261 [05:48<00:00,  3.83it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: project_video_output.mp4
#
# CPU times: user 4min 27s, sys: 36 s, total: 5min 3s
# Wall time: 5min 51s

# %% [markdown]
# ### Playing video inline in notebook

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(video_output1))
# Out:
# <video width="960" height="540" controls>
#   <source src="project_video_output.mp4">
# </video>
